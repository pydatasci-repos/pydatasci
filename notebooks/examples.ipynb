# %%
import os
os.chdir('/Users/layne/Desktop/pydatasci')
os.getcwd()
# Out:
# '/Users/layne/Desktop/pydatasci'

# %%
import pydatasci as pds
from pydatasci import aidb
# Out:
# /Users/layne/.pyenv/versions/3.7.6/envs/jupyterlab/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
from pydatasci.aidb import examples

# %%
from importlib import reload; aidb.delete_db(True); reload(aidb); aidb.create_db()
# Out:
# => Success - deleted database file at path:
# /Users/layne/Library/Application Support/pydatasci/aidb.sqlite3
#
#
# => Success - created database file for machine learning metrics at path:
# /Users/layne/Library/Application Support/pydatasci/aidb.sqlite3
#
#
# => Success - created the following tables within database:
# ['algorithm', 'batch', 'data', 'dataset', 'experiment', 'featureset', 'fold', 'foldset', 'hyperparamcombo', 'hyperparamset', 'job', 'label', 'preprocess', 'result', 'splitset']

# %%
examples.list_demo_files()
# Out:
#                  name                analysis_type    label  label_classes  \
# 0            iris.tsv   classification multi-label  species              3
# 1           sonar.csv  classification binary label   object              2
# 2          houses.csv                   regression    price              1
# 3  iris_noHeaders.csv   classification multi-label  species              3
# 4        iris_10x.tsv   classification multi-label  species              3
#
#    features  samples  \
# 0         4      150
# 1        60      208
# 2        60      506
# 3         4      150
# 4         4     1500
#
#                                                                      description
# 0  3 species of flowers. Only 150 rows, so cross-folds not represent population.
# 1     Detecting either a rock "R" or mine "M". Each feature is a sensor reading.
# 2                                                Predict the price of the house.
# ...

# %%
examples.demo_file_to_pandas('sonar.csv')
# Out:
#           a       b       c       d       e       f       g       h       i  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
examples.list_demo_batches()
# Out:
#                 name supervision        analysis sub_analysis  \
# 0         multiclass  supervised  classification  multi label
# 1             binary  supervised  classification       binary
# 2         regression  supervised      regression         None
# 3  multiclass_folded  supervised  classification  multi label
#
#          validation       dataset
# 0  validation split      iris.tsv
# 1  validation split     sonar.csv
# 2  validation split    houses.csv
# 3       cross-folds  iris_10x.tsv

# %%
#batch1 = examples.make_demo_batch('multiclass')

# %%
#batch1.run_jobs()

# %%
#batch2 = examples.make_demo_batch('multiclass_folded')

# %%
#batch2.run_jobs()

# %%
#batch2.metrics_to_pandas()

# %%
batch3 = examples.make_demo_batch('binary')

# %%
batch3.run_jobs()
# Out:
# 🔮 Training Models 🔮:  25%|██████████▌                               | 1/4 [00:11<00:35, 11.86s/it]
# Process aidb_batch_1:
# Traceback (most recent call last):
#   File "/Users/layne/.pyenv/versions/3.7.6/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/layne/.pyenv/versions/3.7.6/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/layne/Desktop/pydatasci/pydatasci/aidb/__init__.py", line 1349, in background_proc
#     j.run(verbose=verbose)
#   File "/Users/layne/Desktop/pydatasci/pydatasci/aidb/__init__.py", line 1624, in run
#     **hyperparameters
#   File "/Users/layne/Desktop/pydatasci/pydatasci/aidb/examples/__init__.py", line 337, in binary_model_train
#     , callbacks = [History()]
#   File "/Users/layne/.pyenv/versions/3.7.6/envs/jupyterlab/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
# ...

# %%
batch3.metrics_to_pandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
batch4 = examples.make_demo_batch('regression')

# %%
batch4.run_jobs()
# Out:
# Resuming jobs...
# 🔮 Training Models 🔮: 100%|██████████████████████████████████████████| 4/4 [00:18<00:00,  4.69s/it]

# %%
batch4.metrics_to_pandas()
# Out:
#     job_id       split        r2       mse  explained_variance      loss
# 0        2        test  0.814949  0.196238            0.814956  0.196238
# 1        2  validation  0.673494  0.330281            0.673611  0.330281
# 2        2       train  0.788856  0.211144            0.788868  0.211144
# 3        3        test  0.770029  0.243874            0.818798  0.243874
# 4        3  validation  0.608863  0.395660            0.646381  0.395660
# 5        3       train  0.739545  0.260455            0.786466  0.260455
# 6        4        test  0.585565  0.439490            0.592767  0.439490
# 7        4  validation  0.419886  0.586822            0.443650  0.586822
# 8        4       train  0.596558  0.403442            0.611753  0.403442
# 9        5        test  0.780805  0.232447            0.799210  0.232447
# 10       5  validation  0.689365  0.314227            0.703134  0.314227
# 11       5       train  0.765619  0.234381            0.784762  0.234381

# %% [markdown]
# ---

# %%
df = examples.get_demo_file_as_pandas('sonar.csv')

# %%
data = aidb.Data.make(
    dataframe_or_filePath = df
    , label_column_name = 'object'
    , size_test = 0.19
    , size_validation = 0.13
)
